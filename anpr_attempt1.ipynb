# %%
from ultralytics import YOLO
import cv2
from sort.sort import *
import easyocr
from PIL import Image

# %%
coco_model = YOLO('./models/yolov8n.onnx')
mot_tracker = Sort()
license_plate_detector = YOLO('./models/license_plate_detector.onnx')
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify', or 'pose'.
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify', or 'pose'.

# %%
reader = easyocr.Reader(['en'], gpu=False)

vehicles = [2, 3, 5, 6, 7]
plate_text_font = cv2.FONT_HERSHEY_SIMPLEX
plate_text_fontScale = 0.9
plate_text_color = (0, 255, 0)
plate_text_thickness = 2
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
def read_plate(license_plate_crop):
    detections = reader.readtext(license_plate_crop)
    for detection in detections:
        bbox, text, score = detection
        text = text.upper().replace(' ', '')
        print("text detected : "+text)
        return text, score
    return "No_Plate",-1

# %%
def detect_license_plate(vehicle,image,vehicle_detected):
    # vehicle_x1, vehicle_y1, vehicle_x2, vehicle_y2, vehicle_score = vehicle_detected
    vehicle_x1, vehicle_y1, vehicle_x2, vehicle_y2, vehicle_id, vehicle_score, class_id = vehicle_detected
    numberplate_values = []
    numberplates = license_plate_detector(vehicle)[0]
    for numberplate in numberplates.boxes.data.tolist():
        plate_x1, plate_y1, plate_x2, plate_y2, plate_score, plate_id = numberplate
        plate = vehicle[int(plate_y1):int(plate_y2) , int(plate_x1):int(plate_x2)]
        plate_height = plate_y2 - plate_y1
        plate_width = plate_x2 - plate_x1
        cv2.rectangle(image, (int(vehicle_x1 + plate_x1), int(vehicle_y1 + plate_y1)), (int(vehicle_x1 + plate_x1 + plate_width), int(vehicle_y1 + plate_y1 + plate_height)), (0, 255, 0), 2)
        plate_text, plate_text_score = read_plate(plate)
        plate_text_org = (int(vehicle_x1), int(vehicle_y1) + 25) 
        numberplate_values.append([[plate_x1, plate_y1, plate_x2, plate_y2],[vehicle_x1, vehicle_y1, vehicle_x2, vehicle_y2],[int(vehicle_x1 + plate_x1), int(vehicle_y1 + plate_y1), int(vehicle_x1 + plate_x1 + plate_width), int(vehicle_y1 + plate_y1 + plate_height)], plate_score, vehicle_score, plate_text_score, plate_text])
        cv2.putText(image, plate_text, plate_text_org, plate_text_font, plate_text_fontScale, plate_text_color, plate_text_thickness)
        # cv2.imshow("YOLOv8 Tracking", image)
    return numberplate_values

# %%
# Open the video file
video_path = "test-data/sample.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = coco_model.track(frame, persist=True, classes=vehicles)
        # print("\n ------------------------------------- results : -------------------------------\n",results)
        # print("\n -------------------------- results[0].boxes.data.tolist() -------------------- \n",results[0].boxes.data.tolist())
        # Visualize the results on the frame
        for detection in results[0].boxes.data.tolist():
            vehicle_x1, vehicle_y1, vehicle_x2, vehicle_y2, vehicle_id, vehicle_score, class_id = detection
            vehicle = frame[int(vehicle_y1):int(vehicle_y2), int(vehicle_x1):int(vehicle_x2)]
            print(detect_license_plate(vehicle,frame,detection))
            cv2.rectangle(frame, (int(vehicle_x1), int(vehicle_y1)), (int(vehicle_x2), int(vehicle_y2)), (0, 255, 0), 2)
            plate_text_org = (int(vehicle_x1), int(vehicle_y1) - 10) 
            cv2.putText(frame, ("vehicle id : "+str(vehicle_id)), plate_text_org, plate_text_font, plate_text_fontScale, plate_text_color, plate_text_thickness)
        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
        # break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 cars, 1 bus, 1 truck, 251.7ms
# Speed: 6.0ms preprocess, 251.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 251.9ms
# Speed: 6.0ms preprocess, 251.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 544x640 (no detections), 232.8ms
# Speed: 5.0ms preprocess, 232.8ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 1 0, 293.3ms
# Speed: 7.8ms preprocess, 293.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# text detected : WJMRU
# [[[85.82447814941406, 136.2405242919922, 148.3189239501953, 155.0635986328125], [249.43191528320312, 459.6938781738281, 476.0197448730469, 666.3910522460938], [335, 595, 397, 614], 0.7241805791854858, 0.8731617331504822, 0.09524374339383433, 'WJMRU']]
#
# 0: 640x640 (no detections), 632.5ms
# Speed: 13.9ms preprocess, 632.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 500.5ms
# Speed: 15.0ms preprocess, 500.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# [[[74.8184814453125, 141.86984252929688, 131.33010864257812, 158.16404724121094], [731.0836791992188, 384.48944091796875, 933.1014404296875, 580.755615234375], [805, 526, 862, 542], 0.720414936542511, 0.7919327020645142, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 240.1ms
# Speed: 8.0ms preprocess, 240.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 192x640 (no detections), 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# []
#
# 0: 384x640 (no detections), 239.5ms
# Speed: 11.0ms preprocess, 239.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 512x640 (no detections), 214.6ms
# Speed: 6.0ms preprocess, 214.6ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 332.6ms
# Speed: 6.0ms preprocess, 332.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 608x640 (no detections), 368.2ms
# Speed: 9.4ms preprocess, 368.2ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 361.3ms
# Speed: 14.0ms preprocess, 361.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 451.6ms
# Speed: 12.0ms preprocess, 451.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 358.3ms
# Speed: 13.4ms preprocess, 358.3ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 544x640 (no detections), 251.8ms
# Speed: 9.1ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 386.2ms
# Speed: 8.0ms preprocess, 386.2ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 307.6ms
# Speed: 10.8ms preprocess, 307.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 315.0ms
# Speed: 5.9ms preprocess, 315.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [[[73.8950424194336, 144.9407501220703, 131.6179962158203, 162.23178100585938], [731.8878784179688, 381.93853759765625, 930.8168334960938, 581.5219116210938], [805, 526, 863, 544], 0.868033230304718, 0.810696542263031, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 246.3ms
# Speed: 5.5ms preprocess, 246.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 192x640 (no detections), 121.6ms
# Speed: 2.4ms preprocess, 121.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 640)
# []
#
# 0: 384x640 (no detections), 214.1ms
# Speed: 3.7ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 512x640 (no detections), 338.0ms
# Speed: 6.0ms preprocess, 338.0ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 323.5ms
# Speed: 9.1ms preprocess, 323.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 576x640 (no detections), 231.1ms
# Speed: 6.0ms preprocess, 231.1ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 313.1ms
# Speed: 7.8ms preprocess, 313.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 202.0ms
# Speed: 20.0ms preprocess, 202.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 251.0ms
# Speed: 7.0ms preprocess, 251.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 512x640 (no detections), 229.8ms
# Speed: 4.0ms preprocess, 229.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 300.2ms
# Speed: 6.9ms preprocess, 300.2ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 275.6ms
# Speed: 6.0ms preprocess, 275.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 280.3ms
# Speed: 6.8ms preprocess, 280.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [[[73.8591537475586, 141.39500427246094, 131.9022979736328, 157.44351196289062], [731.252685546875, 387.20074462890625, 931.5511474609375, 583.6201171875], [805, 528, 863, 544], 0.7633059024810791, 0.8248152136802673, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 271.1ms
# Speed: 6.0ms preprocess, 271.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 160x640 (no detections), 102.9ms
# Speed: 3.8ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 640)
# []
#
# 0: 384x640 (no detections), 187.8ms
# Speed: 4.0ms preprocess, 187.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 247.0ms
# Speed: 6.0ms preprocess, 247.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 576x640 (no detections), 265.1ms
# Speed: 7.0ms preprocess, 265.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 608x640 (no detections), 270.5ms
# Speed: 7.2ms preprocess, 270.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 283.5ms
# Speed: 8.0ms preprocess, 283.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 189.0ms
# Speed: 6.0ms preprocess, 189.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 298.4ms
# Speed: 6.0ms preprocess, 298.4ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 512x640 (no detections), 237.3ms
# Speed: 4.5ms preprocess, 237.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 1 0, 259.0ms
# Speed: 6.7ms preprocess, 259.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# [[[84.15161895751953, 142.41262817382812, 144.92543029785156, 160.96243286132812], [248.11656188964844, 461.8498840332031, 477.083251953125, 669.7459106445312], [332, 604, 393, 622], 0.48388051986694336, 0.8777977228164673, -1, 'No_Plate']]
#
# 0: 640x640 (no detections), 300.6ms
# Speed: 7.0ms preprocess, 300.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 293.4ms
# Speed: 8.6ms preprocess, 293.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# text detected : WH
# [[[74.23902130126953, 140.85791015625, 132.06802368164062, 157.54319763183594], [731.2125244140625, 390.0273742675781, 931.4931030273438, 585.9093627929688], [805, 530, 863, 547], 0.7627884149551392, 0.8543493151664734, 0.25740575941877897, 'WH']]
#
# 0: 544x640 (no detections), 213.5ms
# Speed: 6.0ms preprocess, 213.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 160x640 (no detections), 220.4ms
# Speed: 2.3ms preprocess, 220.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 640)
# []
#
# 0: 384x640 (no detections), 188.0ms
# Speed: 4.0ms preprocess, 188.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 243.8ms
# Speed: 4.5ms preprocess, 243.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 576x640 (no detections), 245.0ms
# Speed: 5.9ms preprocess, 245.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 608x640 (no detections), 287.5ms
# Speed: 6.0ms preprocess, 287.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 283.0ms
# Speed: 9.0ms preprocess, 283.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 188.0ms
# Speed: 11.0ms preprocess, 188.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 243.0ms
# Speed: 7.4ms preprocess, 243.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 512x640 (no detections), 222.6ms
# Speed: 5.9ms preprocess, 222.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 289.1ms
# Speed: 8.0ms preprocess, 289.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 270.8ms
# Speed: 6.0ms preprocess, 270.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 289.6ms
# Speed: 7.0ms preprocess, 289.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [[[75.33296966552734, 142.9379119873047, 133.74154663085938, 159.09373474121094], [730.447509765625, 389.9595947265625, 932.466064453125, 587.4342651367188], [805, 532, 864, 549], 0.7097510099411011, 0.8506693840026855, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 270.2ms
# Speed: 8.8ms preprocess, 270.2ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 160x640 (no detections), 86.5ms
# Speed: 2.4ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 640)
# []
#
# 0: 384x640 (no detections), 160.5ms
# Speed: 4.0ms preprocess, 160.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 227.9ms
# Speed: 5.0ms preprocess, 227.9ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 284.7ms
# Speed: 6.0ms preprocess, 284.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 608x640 (no detections), 288.7ms
# Speed: 7.0ms preprocess, 288.7ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 279.2ms
# Speed: 8.0ms preprocess, 279.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 184.0ms
# Speed: 4.0ms preprocess, 184.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 290.9ms
# Speed: 6.3ms preprocess, 290.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 512x640 (no detections), 211.1ms
# Speed: 7.0ms preprocess, 211.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 259.0ms
# Speed: 7.9ms preprocess, 259.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 278.0ms
# Speed: 6.3ms preprocess, 278.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 306.0ms
# Speed: 9.0ms preprocess, 306.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# text detected : LIIKS
# [[[75.56494903564453, 144.25489807128906, 133.8372802734375, 161.0620880126953], [730.039306640625, 390.73333740234375, 933.9684448242188, 589.3621826171875], [805, 534, 863, 551], 0.6714763641357422, 0.863048255443573, 0.05674832548173899, 'LIIKS']]
#
# 0: 544x640 (no detections), 239.4ms
# Speed: 8.0ms preprocess, 239.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 160x640 (no detections), 87.0ms
# Speed: 2.7ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 640)
# []
#
# 0: 384x640 (no detections), 188.1ms
# Speed: 4.0ms preprocess, 188.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 368.6ms
# Speed: 16.0ms preprocess, 368.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 576x640 (no detections), 240.9ms
# Speed: 6.0ms preprocess, 240.9ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 608x640 (no detections), 251.0ms
# Speed: 7.0ms preprocess, 251.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 289.7ms
# Speed: 9.0ms preprocess, 289.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 184.6ms
# Speed: 8.0ms preprocess, 184.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 263.0ms
# Speed: 5.5ms preprocess, 263.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 512x640 (no detections), 248.0ms
# Speed: 4.7ms preprocess, 248.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 261.2ms
# Speed: 7.0ms preprocess, 261.2ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 245.6ms
# Speed: 6.0ms preprocess, 245.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 281.0ms
# Speed: 7.0ms preprocess, 281.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [[[77.04940795898438, 147.0992889404297, 135.33006286621094, 164.9935302734375], [729.8650512695312, 389.0527648925781, 938.8056640625, 590.52490234375], [806, 536, 865, 554], 0.5606760382652283, 0.8270543217658997, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 254.3ms
# Speed: 9.0ms preprocess, 254.3ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 160x640 (no detections), 86.5ms
# Speed: 4.1ms preprocess, 86.5ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 640)
# []
#
# 0: 384x640 (no detections), 151.7ms
# Speed: 7.0ms preprocess, 151.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 213.1ms
# Speed: 4.7ms preprocess, 213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 246.9ms
# Speed: 7.0ms preprocess, 246.9ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 576x640 (no detections), 265.4ms
# Speed: 7.0ms preprocess, 265.4ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 253.6ms
# Speed: 7.0ms preprocess, 253.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 184.9ms
# Speed: 4.1ms preprocess, 184.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 276.1ms
# Speed: 5.0ms preprocess, 276.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 512x640 (no detections), 227.2ms
# Speed: 4.0ms preprocess, 227.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 240.7ms
# Speed: 31.4ms preprocess, 240.7ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 258.3ms
# Speed: 7.7ms preprocess, 258.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 608x640 1 0, 281.4ms
# Speed: 8.0ms preprocess, 281.4ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# text detected : LLIS
# [[[77.28813934326172, 146.00897216796875, 135.73057556152344, 163.05532836914062], [729.260986328125, 391.7287902832031, 940.6253051757812, 591.786376953125], [806, 537, 864, 554], 0.742575466632843, 0.8232220411300659, 0.24018161792795906, 'LLIS']]
#
# 0: 576x640 (no detections), 225.6ms
# Speed: 5.0ms preprocess, 225.6ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 160x640 (no detections), 80.7ms
# Speed: 1.6ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 640)
# []
#
# 0: 384x640 (no detections), 167.2ms
# Speed: 5.4ms preprocess, 167.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 244.6ms
# Speed: 5.0ms preprocess, 244.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 276.0ms
# Speed: 8.1ms preprocess, 276.0ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 576x640 1 0, 320.6ms
# Speed: 54.0ms preprocess, 320.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# [[[0.0, 0.0, 97.88172912597656, 87.0], [710.3407592773438, 150.6636199951172, 808.4877319335938, 237.34555053710938], [710, 150, 808, 237], 0.31857478618621826, 0.6149075627326965, -1, 'No_Plate']]
#
# 0: 640x640 (no detections), 302.0ms
# Speed: 7.0ms preprocess, 302.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 192.0ms
# Speed: 9.1ms preprocess, 192.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 244.0ms
# Speed: 5.9ms preprocess, 244.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 512x640 (no detections), 237.1ms
# Speed: 4.0ms preprocess, 237.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 295.6ms
# Speed: 9.0ms preprocess, 295.6ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 275.3ms
# Speed: 6.8ms preprocess, 275.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 608x640 1 0, 252.9ms
# Speed: 7.0ms preprocess, 252.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# text detected : HIIU
# [[[75.91950988769531, 143.7330780029297, 134.81187438964844, 161.09112548828125], [731.4515380859375, 396.1551208496094, 940.3099975585938, 594.0541381835938], [807, 539, 866, 557], 0.8202736377716064, 0.8155986070632935, 0.2859612703323364, 'HIIU']]
#
# 0: 544x640 (no detections), 260.5ms
# Speed: 7.1ms preprocess, 260.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 128x640 (no detections), 106.2ms
# Speed: 2.2ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
# []
#
# 0: 384x640 (no detections), 186.7ms
# Speed: 5.0ms preprocess, 186.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 229.1ms
# Speed: 6.0ms preprocess, 229.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 275.2ms
# Speed: 6.5ms preprocess, 275.2ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 576x640 (no detections), 239.7ms
# Speed: 6.0ms preprocess, 239.7ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 263.2ms
# Speed: 9.0ms preprocess, 263.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 191.7ms
# Speed: 5.0ms preprocess, 191.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 276.4ms
# Speed: 8.7ms preprocess, 276.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 512x640 (no detections), 214.5ms
# Speed: 4.0ms preprocess, 214.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 243.6ms
# Speed: 7.0ms preprocess, 243.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 640x640 (no detections), 286.9ms
# Speed: 6.0ms preprocess, 286.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 608x640 1 0, 282.3ms
# Speed: 9.0ms preprocess, 282.3ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
# [[[74.27086639404297, 144.12451171875, 135.02403259277344, 161.0514373779297], [732.0682373046875, 398.4652099609375, 942.7811889648438, 596.620361328125], [806, 542, 867, 559], 0.7680468559265137, 0.7576266527175903, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 218.8ms
# Speed: 6.9ms preprocess, 218.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 128x640 (no detections), 74.1ms
# Speed: 1.0ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 640)
# []
#
# 0: 384x640 (no detections), 160.2ms
# Speed: 5.0ms preprocess, 160.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 250.9ms
# Speed: 5.8ms preprocess, 250.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 256.1ms
# Speed: 7.0ms preprocess, 256.1ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 576x640 (no detections), 238.2ms
# Speed: 6.6ms preprocess, 238.2ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 380.8ms
# Speed: 8.0ms preprocess, 380.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 11 cars, 1 bus, 1 truck, 211.2ms
# Speed: 7.0ms preprocess, 211.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 234.0ms
# Speed: 5.5ms preprocess, 234.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 512x640 (no detections), 207.0ms
# Speed: 4.9ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 1 0, 272.9ms
# Speed: 7.0ms preprocess, 272.9ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
# text detected : HAIJHRU
# [[[88.89179229736328, 146.85299682617188, 171.62399291992188, 166.0609588623047], [234.97067260742188, 474.3503723144531, 471.1125793457031, 690.2416381835938], [323, 621, 406, 640], 0.2959762513637543, 0.8930160403251648, 0.18556668379765345, 'HAIJHRU']]
#
# 0: 640x640 (no detections), 261.2ms
# Speed: 7.0ms preprocess, 261.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 608x640 1 0, 254.2ms
# Speed: 6.0ms preprocess, 254.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# text detected : WEMW
# [[[74.0395278930664, 145.26522827148438, 133.2386016845703, 161.38406372070312], [732.9037475585938, 399.4856262207031, 943.4102172851562, 598.2850341796875], [806, 544, 866, 560], 0.8376726508140564, 0.7498005628585815, 0.06070037931203842, 'WEMW']]
#
# 0: 544x640 (no detections), 262.7ms
# Speed: 5.0ms preprocess, 262.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 96x640 (no detections), 84.0ms
# Speed: 0.7ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 640)
# []
#
# 0: 384x640 (no detections), 185.2ms
# Speed: 4.3ms preprocess, 185.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 234.0ms
# Speed: 5.6ms preprocess, 234.0ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 246.5ms
# Speed: 5.7ms preprocess, 246.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 576x640 (no detections), 270.6ms
# Speed: 8.0ms preprocess, 270.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 260.6ms
# Speed: 6.0ms preprocess, 260.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 320x640 (no detections), 154.2ms
# Speed: 3.0ms preprocess, 154.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# []
#
# 0: 384x640 11 cars, 1 bus, 1 truck, 185.1ms
# Speed: 6.0ms preprocess, 185.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 281.6ms
# Speed: 6.0ms preprocess, 281.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 512x640 (no detections), 224.9ms
# Speed: 5.0ms preprocess, 224.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 1 0, 266.9ms
# Speed: 7.0ms preprocess, 266.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# text detected : NAI3MRU
# [[[88.05123901367188, 148.01824951171875, 154.25955200195312, 167.50991821289062], [233.81430053710938, 476.3179016113281, 469.16265869140625, 693.2662353515625], [321, 624, 388, 643], 0.5000445246696472, 0.8866750001907349, 0.22224718756596706, 'NAI3MRU']]
#
# 0: 640x640 (no detections), 306.5ms
# Speed: 8.0ms preprocess, 306.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 291.1ms
# Speed: 9.0ms preprocess, 291.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [[[72.85009765625, 147.2288055419922, 133.36607360839844, 164.97215270996094], [733.1481323242188, 398.7680969238281, 942.5370483398438, 600.4585571289062], [805, 545, 866, 563], 0.6031242609024048, 0.7450187802314758, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 309.9ms
# Speed: 7.9ms preprocess, 309.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 96x640 (no detections), 104.3ms
# Speed: 2.0ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 96, 640)
# []
#
# 0: 384x640 (no detections), 193.7ms
# Speed: 4.4ms preprocess, 193.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 288.1ms
# Speed: 6.0ms preprocess, 288.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 (no detections), 267.0ms
# Speed: 6.1ms preprocess, 267.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 576x640 (no detections), 418.2ms
# Speed: 7.1ms preprocess, 418.2ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 284.7ms
# Speed: 9.5ms preprocess, 284.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 288x640 (no detections), 150.3ms
# Speed: 2.1ms preprocess, 150.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
# []
#
# 0: 384x640 11 cars, 1 bus, 1 truck, 196.6ms
# Speed: 7.0ms preprocess, 196.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 284.3ms
# Speed: 6.5ms preprocess, 284.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 512x640 (no detections), 227.9ms
# Speed: 5.0ms preprocess, 227.9ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 1 0, 246.9ms
# Speed: 6.0ms preprocess, 246.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# text detected : MAIJMRU
# [[[88.23839569091797, 147.80441284179688, 158.08673095703125, 167.62255859375], [232.14109802246094, 479.96051025390625, 468.26251220703125, 696.6212768554688], [320, 627, 390, 647], 0.45217305421829224, 0.8853379487991333, 0.12246351111937, 'MAIJMRU']]
#
# 0: 640x640 (no detections), 304.9ms
# Speed: 6.8ms preprocess, 304.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 277.8ms
# Speed: 7.0ms preprocess, 277.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [[[76.03472137451172, 147.41775512695312, 135.7023162841797, 165.71653747558594], [732.4265747070312, 400.7525634765625, 940.7037353515625, 602.7046508789062], [808, 548, 868, 566], 0.7888193130493164, 0.7921485900878906, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 245.5ms
# Speed: 7.5ms preprocess, 245.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 384x640 (no detections), 222.9ms
# Speed: 4.1ms preprocess, 222.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 512x640 (no detections), 216.9ms
# Speed: 4.8ms preprocess, 216.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 (no detections), 273.4ms
# Speed: 18.1ms preprocess, 273.4ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# []
#
# 0: 544x640 (no detections), 224.6ms
# Speed: 5.0ms preprocess, 224.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 640x640 (no detections), 291.6ms
# Speed: 6.6ms preprocess, 291.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 288x640 (no detections), 139.0ms
# Speed: 2.8ms preprocess, 139.0ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
# []
#
# 0: 224x640 (no detections), 123.1ms
# Speed: 3.8ms preprocess, 123.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 640)
# []
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 192.0ms
# Speed: 4.0ms preprocess, 192.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 247.9ms
# Speed: 6.9ms preprocess, 247.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 512x640 (no detections), 245.9ms
# Speed: 5.0ms preprocess, 245.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 1 0, 247.7ms
# Speed: 11.0ms preprocess, 247.7ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
# text detected : MAIJHRU
# [[[76.51254272460938, 147.83514404296875, 155.8500518798828, 167.2472381591797], [230.693603515625, 481.48052978515625, 467.90350341796875, 697.89599609375], [307, 629, 386, 648], 0.41651850938796997, 0.8678802847862244, 0.0849621770938853, 'MAIJHRU']]
#
# 0: 640x640 (no detections), 297.6ms
# Speed: 6.8ms preprocess, 297.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 554.2ms
# Speed: 7.0ms preprocess, 554.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# text detected : WSLSU
# [[[76.50556945800781, 147.9252166748047, 135.7091064453125, 166.05947875976562], [732.8735961914062, 400.5145263671875, 939.4151611328125, 604.0120849609375], [809, 548, 868, 566], 0.8174620270729065, 0.7672116160392761, 0.09189575627994749, 'WSLSU']]
#
# 0: 544x640 (no detections), 268.5ms
# Speed: 5.7ms preprocess, 268.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 384x640 (no detections), 197.4ms
# Speed: 3.3ms preprocess, 197.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 544x640 (no detections), 261.3ms
# Speed: 6.0ms preprocess, 261.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 608x640 1 0, 254.9ms
# Speed: 6.0ms preprocess, 254.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# [[[0.0392635315656662, 0.0, 65.90541076660156, 61.0], [210.75563049316406, 193.9796905517578, 276.20611572265625, 254.80038452148438], [210, 193, 276, 254], 0.4007216691970825, 0.5289992690086365, -1, 'No_Plate']]
#
# 0: 576x640 (no detections), 315.5ms
# Speed: 8.0ms preprocess, 315.5ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 272.2ms
# Speed: 6.0ms preprocess, 272.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 320x640 (no detections), 140.2ms
# Speed: 2.7ms preprocess, 140.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# []
#
# 0: 224x640 (no detections), 117.7ms
# Speed: 2.4ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 640)
# []
#
# 0: 384x640 (no detections), 191.7ms
# Speed: 4.0ms preprocess, 191.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 215.0ms
# Speed: 7.1ms preprocess, 215.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 252.1ms
# Speed: 6.0ms preprocess, 252.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 512x640 (no detections), 234.6ms
# Speed: 5.0ms preprocess, 234.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# []
#
# 0: 608x640 1 0, 297.6ms
# Speed: 7.0ms preprocess, 297.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# text detected : WAIZHRU
# [[[83.6314468383789, 148.70030212402344, 152.78298950195312, 168.34481811523438], [230.17742919921875, 483.4862365722656, 467.4530944824219, 701.3165893554688], [313, 632, 382, 651], 0.40764120221138, 0.8816909790039062, 0.16635986050722165, 'WAIZHRU']]
#
# 0: 640x640 (no detections), 262.4ms
# Speed: 6.0ms preprocess, 262.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 640x640 1 0, 292.2ms
# Speed: 8.0ms preprocess, 292.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# [[[76.2663803100586, 148.87301635742188, 135.7923126220703, 166.28111267089844], [733.489013671875, 402.8466796875, 940.7457885742188, 605.4537353515625], [809, 551, 869, 569], 0.8546149134635925, 0.7686116099357605, -1, 'No_Plate']]
#
# 0: 544x640 (no detections), 249.7ms
# Speed: 7.0ms preprocess, 249.7ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 416x640 (no detections), 197.9ms
# Speed: 4.6ms preprocess, 197.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# []
#
# 0: 544x640 (no detections), 238.6ms
# Speed: 6.0ms preprocess, 238.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# []
#
# 0: 576x640 (no detections), 282.0ms
# Speed: 6.0ms preprocess, 282.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 576x640 (no detections), 245.0ms
# Speed: 16.0ms preprocess, 245.0ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# []
#
# 0: 640x640 (no detections), 283.0ms
# Speed: 7.0ms preprocess, 283.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# []
#
# 0: 384x640 (no detections), 157.0ms
# Speed: 4.8ms preprocess, 157.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# []
#
# 0: 224x640 (no detections), 111.0ms
# Speed: 3.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 640)
# []
#
# 0: 384x640 (no detections), 192.2ms
# Speed: 3.9ms preprocess, 192.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# []

# %% [markdown]
# # Image

# %%
def vehicle_detection_and_recognition(image):
    detections = coco_model(image)[0]
    vehicle_detections = []
    for detection in detections.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = detection
        if int(class_id) in vehicles:
            vehicle_detections.append([x1, y1, x2, y2, score])
    # for vehicle_detected in vehicle_detections:
    #     vehicle_x1, vehicle_y1, vehicle_x2, vehicle_y2, vehicle_score = vehicle_detected
    #     vehicle = image[int(vehicle_y1):int(vehicle_y2), int(vehicle_x1):int(vehicle_x2)]
    #     cv2.rectangle(image, (int(vehicle_x1), int(vehicle_y1)), (int(vehicle_x2), int(vehicle_y2)), (0, 255, 0), 2)
    #     print(detect_license_plate(vehicle,image,vehicle_detected))
        print(vehicle_detections)

# %%
image = cv2.imread('test-data/image2.jpg')
vehicle_detection_and_recognition(image)
cv2.imshow('Image After Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Loading models\yolov8n.onnx for ONNX Runtime inference...
# requirements: Ultralytics requirement ['onnxruntime'] not found, attempting AutoUpdate...
# Collecting onnxruntime
#   Downloading onnxruntime-1.16.3-cp39-cp39-win_amd64.whl.metadata (4.5 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in c:\python39\lib\site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: numpy>=1.21.6 in c:\python39\lib\site-packages (from onnxruntime) (1.22.4)
# Requirement already satisfied: packaging in c:\python39\lib\site-packages (from onnxruntime) (21.0)
# Requirement already satisfied: protobuf in c:\python39\lib\site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in c:\python39\lib\site-packages (from onnxruntime) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.0.2 in c:\python39\lib\site-packages (from packaging->onnxruntime) (2.4.7)
# Requirement already satisfied: mpmath>=0.19 in c:\python39\lib\site-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\python39\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime) (3.4.1)
# Downloading onnxruntime-1.16.3-cp39-cp39-win_amd64.whl (7.3 MB)
#    ---------------------------------------- 7.3/7.3 MB 2.3 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.16.3
#
# requirements: AutoUpdate success ✅ 14.4s, installed 1 package: ['onnxruntime']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 640x640 4 cars, 290.7ms
# Speed: 27.0ms preprocess, 290.7ms inference, 41.0ms postprocess per image at shape (1, 3, 640, 640)
# [[566.7183227539062, 12.633399963378906, 1325.7371826171875, 482.9703369140625, 0.8249082565307617]]
# [[566.7183227539062, 12.633399963378906, 1325.7371826171875, 482.9703369140625, 0.8249082565307617], [324.4737243652344, 103.93415069580078, 495.2755432128906, 232.47781372070312, 0.8116979002952576]]
# [[566.7183227539062, 12.633399963378906, 1325.7371826171875, 482.9703369140625, 0.8249082565307617], [324.4737243652344, 103.93415069580078, 495.2755432128906, 232.47781372070312, 0.8116979002952576], [222.71524047851562, 129.6041717529297, 283.1064758300781, 170.41604614257812, 0.6494941711425781]]
# [[566.7183227539062, 12.633399963378906, 1325.7371826171875, 482.9703369140625, 0.8249082565307617], [324.4737243652344, 103.93415069580078, 495.2755432128906, 232.47781372070312, 0.8116979002952576], [222.71524047851562, 129.6041717529297, 283.1064758300781, 170.41604614257812, 0.6494941711425781], [173.03546142578125, 132.62893676757812, 204.56942749023438, 158.1029510498047, 0.43685805797576904]]
